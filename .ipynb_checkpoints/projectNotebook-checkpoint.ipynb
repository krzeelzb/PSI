# %%
import pandas as pd
import numpy as np
import os
from tabulate import tabulate

from sklearn.preprocessing import minmax_scale

pd.set_option('display.max_columns',15)
import sklearn.preprocessing as sk

import warnings
warnings.filterwarnings('ignore')

# %%
def preprocesProcedura(file):
    data = pd.read_csv(file, sep="\t", header=None)
    data.columns = ['id', 'stimulusId', 'consistency', 'picture_sound_pos_neg', 'sound_number', 'picture_number','choose_type', 'not_processed_answer', 'answer_time', 'stimulus_time']
    answer=''
    # data.dropna()
    data = (data[['id', 'consistency', 'picture_sound_pos_neg', 'sound_number', 'picture_number', 'choose_type','not_processed_answer']].copy())
    data = data[data['consistency'] == 'inc']
    data = data[data['choose_type'] == 'emospace1']
    data = (data[['id', 'picture_sound_pos_neg', 'sound_number', 'picture_number', 'not_processed_answer']].copy())

    answer=data['not_processed_answer']
    answer_valence=[]
    answer_arousal=[]

    for i in answer:
        a=i[1:]
        a=a[:-1]
        a=a.split(', ',1)

        answer_valence.append(float(a[0]))
        answer_arousal.append(float(a[1]))


    answer_valance_scaled = minmax_scale(answer_valence, feature_range=(1,9))
    answer_arousal_scaled = minmax_scale(answer_arousal, feature_range=(1,9))

    data['answer_valence']=answer_valance_scaled
    data['answer_valence']=data['answer_valence'].astype("float")
    data['answer_arousal']=answer_arousal_scaled
    data['answer_arousal']=data['answer_arousal'].astype("float")

    pictures_data = preprocesPictures()
    sounds_data = preprocesSounds()


    # print(pictures_data)
    # print(pictures_data.dtypes)


    data = data.merge(sounds_data, on='sound_number')
    data = data.merge(pictures_data, on='picture_number')

    # data['picture_sound_pos_neg'] = data['picture_sound_pos_neg'].apply(lambda x : str(convert_to_pos_neg(x)))
    is_picture_pos = []
    is_sound_pos = []



    for i in data['picture_sound_pos_neg']:
        if i == "p+s-":
            is_picture_pos.append(1)
            is_sound_pos.append(0)
        else:
            is_picture_pos.append(0)
            is_sound_pos.append(1)

    data['is_picture_positive'] = is_picture_pos
    data['is_sound_positive'] = is_sound_pos

    data = (data[['id', 'sound_number', 'sound_valence_mean', 'sound_arousal_mean', 'is_sound_positive', 'is_sound_obscene',
                  'picture_number', 'picture_arousal_mean', 'picture_valence_mean', 'is_picture_positive', 'is_picture_obscene',
                  'not_processed_answer', 'answer_valence', 'answer_arousal']].copy())

    # print("PO JOINIE")
    #print(tabulate(data, headers='keys', tablefmt='psql'))
    #print(data.dtypes)

    return data


def preprocesPictures():
    data=pd.read_csv('IAPS.csv',sep=';')
    data = (data[['Description', 'IAPS', 'ValenceMean', 'ArousalMean']].copy())
    data.columns = ['is_picture_obscene', 'picture_number', 'picture_valence_mean', 'picture_arousal_mean']
    data['picture_number'] = data['picture_number'].apply(lambda x : x.replace(',', ''))
    data['picture_number'] = data['picture_number'].apply(lambda x : int(x))
    data['picture_valence_mean'] = data['picture_valence_mean'].apply(lambda x : x.replace(',', '.'))
    data['picture_arousal_mean'] = data['picture_arousal_mean'].apply(lambda x : x.replace(',', '.'))
    data['picture_valence_mean'] = data['picture_valence_mean'].apply(lambda x : float(x))
    data['picture_arousal_mean'] = data['picture_arousal_mean'].apply(lambda x : float(x))
    data['is_picture_obscene'] = data['is_picture_obscene'].apply(lambda  x : is_obscene(x))
    data['is_picture_obscene'] = data['is_picture_obscene'].astype("int")
    return data


def preprocesSounds():
    data = pd.read_csv('IADS2.csv', sep=';')
    data = (data[['Sound', 'Number', 'ValenceMean', 'ArousalMean']].copy())
    data.columns = ['is_sound_obscene', 'sound_number', 'sound_valence_mean', 'sound_arousal_mean']
    data['is_sound_obscene'] = data['is_sound_obscene'].apply(lambda  x : is_obscene(x))
    data['is_sound_obscene'] = data['is_sound_obscene'].astype("int")
    return data

def is_obscene(description):
    if description[:6] == 'Erotic' or description[0:4] == 'Nude':
        return '1'
    else:
        return '0'

def convert_to_pos_neg(pXsX):
    if pXsX == "p-s+":
        to_return = [-1,1]
        return to_return
    elif pXsX == "p+s-":
        to_return = [1,-1]
        return to_return
    else:
        return {0,2}


# print("PICTURES")
# preprocesPictures()
# print("SOUDS")
# preprocesSounds()

# %%
filesToProcess = []

directory = os.fsencode('proceduraTXT')
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    filesToProcess.append(preprocesProcedura('proceduraTXT/'+filename))
    df = pd.concat(filesToProcess, ignore_index=True)
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 14 columns):
# id                      28 non-null int64
# sound_number            28 non-null int64
# sound_valence_mean      28 non-null float64
# sound_arousal_mean      28 non-null float64
# is_sound_positive       28 non-null int64
# is_sound_obscene        28 non-null int64
# picture_number          28 non-null int64
# picture_arousal_mean    28 non-null float64
# picture_valence_mean    28 non-null float64
# is_picture_positive     28 non-null int64
# is_picture_obscene      28 non-null int64
# not_processed_answer    28 non-null object
# answer_valence          28 non-null float64
# answer_arousal          28 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 3.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 14 columns):
# id                      60 non-null int64
# sound_number            60 non-null int64
# sound_valence_mean      60 non-null float64
# sound_arousal_mean      60 non-null float64
# is_sound_positive       60 non-null int64
# is_sound_obscene        60 non-null int64
# picture_number          60 non-null int64
# picture_arousal_mean    60 non-null float64
# picture_valence_mean    60 non-null float64
# is_picture_positive     60 non-null int64
# is_picture_obscene      60 non-null int64
# not_processed_answer    60 non-null object
# answer_valence          60 non-null float64
# answer_arousal          60 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 6.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 14 columns):
# id                      94 non-null int64
# sound_number            94 non-null int64
# sound_valence_mean      94 non-null float64
# sound_arousal_mean      94 non-null float64
# is_sound_positive       94 non-null int64
# is_sound_obscene        94 non-null int64
# picture_number          94 non-null int64
# picture_arousal_mean    94 non-null float64
# picture_valence_mean    94 non-null float64
# is_picture_positive     94 non-null int64
# is_picture_obscene      94 non-null int64
# not_processed_answer    94 non-null object
# answer_valence          94 non-null float64
# answer_arousal          94 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 10.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 14 columns):
# id                      124 non-null int64
# sound_number            124 non-null int64
# sound_valence_mean      124 non-null float64
# sound_arousal_mean      124 non-null float64
# is_sound_positive       124 non-null int64
# is_sound_obscene        124 non-null int64
# picture_number          124 non-null int64
# picture_arousal_mean    124 non-null float64
# picture_valence_mean    124 non-null float64
# is_picture_positive     124 non-null int64
# is_picture_obscene      124 non-null int64
# not_processed_answer    124 non-null object
# answer_valence          124 non-null float64
# answer_arousal          124 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 13.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 14 columns):
# id                      150 non-null int64
# sound_number            150 non-null int64
# sound_valence_mean      150 non-null float64
# sound_arousal_mean      150 non-null float64
# is_sound_positive       150 non-null int64
# is_sound_obscene        150 non-null int64
# picture_number          150 non-null int64
# picture_arousal_mean    150 non-null float64
# picture_valence_mean    150 non-null float64
# is_picture_positive     150 non-null int64
# is_picture_obscene      150 non-null int64
# not_processed_answer    150 non-null object
# answer_valence          150 non-null float64
# answer_arousal          150 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 16.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 14 columns):
# id                      183 non-null int64
# sound_number            183 non-null int64
# sound_valence_mean      183 non-null float64
# sound_arousal_mean      183 non-null float64
# is_sound_positive       183 non-null int64
# is_sound_obscene        183 non-null int64
# picture_number          183 non-null int64
# picture_arousal_mean    183 non-null float64
# picture_valence_mean    183 non-null float64
# is_picture_positive     183 non-null int64
# is_picture_obscene      183 non-null int64
# not_processed_answer    183 non-null object
# answer_valence          183 non-null float64
# answer_arousal          183 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 20.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 14 columns):
# id                      208 non-null int64
# sound_number            208 non-null int64
# sound_valence_mean      208 non-null float64
# sound_arousal_mean      208 non-null float64
# is_sound_positive       208 non-null int64
# is_sound_obscene        208 non-null int64
# picture_number          208 non-null int64
# picture_arousal_mean    208 non-null float64
# picture_valence_mean    208 non-null float64
# is_picture_positive     208 non-null int64
# is_picture_obscene      208 non-null int64
# not_processed_answer    208 non-null object
# answer_valence          208 non-null float64
# answer_arousal          208 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 22.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 14 columns):
# id                      239 non-null int64
# sound_number            239 non-null int64
# sound_valence_mean      239 non-null float64
# sound_arousal_mean      239 non-null float64
# is_sound_positive       239 non-null int64
# is_sound_obscene        239 non-null int64
# picture_number          239 non-null int64
# picture_arousal_mean    239 non-null float64
# picture_valence_mean    239 non-null float64
# is_picture_positive     239 non-null int64
# is_picture_obscene      239 non-null int64
# not_processed_answer    239 non-null object
# answer_valence          239 non-null float64
# answer_arousal          239 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 26.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 14 columns):
# id                      269 non-null int64
# sound_number            269 non-null int64
# sound_valence_mean      269 non-null float64
# sound_arousal_mean      269 non-null float64
# is_sound_positive       269 non-null int64
# is_sound_obscene        269 non-null int64
# picture_number          269 non-null int64
# picture_arousal_mean    269 non-null float64
# picture_valence_mean    269 non-null float64
# is_picture_positive     269 non-null int64
# is_picture_obscene      269 non-null int64
# not_processed_answer    269 non-null object
# answer_valence          269 non-null float64
# answer_arousal          269 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 29.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 14 columns):
# id                      298 non-null int64
# sound_number            298 non-null int64
# sound_valence_mean      298 non-null float64
# sound_arousal_mean      298 non-null float64
# is_sound_positive       298 non-null int64
# is_sound_obscene        298 non-null int64
# picture_number          298 non-null int64
# picture_arousal_mean    298 non-null float64
# picture_valence_mean    298 non-null float64
# is_picture_positive     298 non-null int64
# is_picture_obscene      298 non-null int64
# not_processed_answer    298 non-null object
# answer_valence          298 non-null float64
# answer_arousal          298 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 32.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 14 columns):
# id                      331 non-null int64
# sound_number            331 non-null int64
# sound_valence_mean      331 non-null float64
# sound_arousal_mean      331 non-null float64
# is_sound_positive       331 non-null int64
# is_sound_obscene        331 non-null int64
# picture_number          331 non-null int64
# picture_arousal_mean    331 non-null float64
# picture_valence_mean    331 non-null float64
# is_picture_positive     331 non-null int64
# is_picture_obscene      331 non-null int64
# not_processed_answer    331 non-null object
# answer_valence          331 non-null float64
# answer_arousal          331 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 36.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 14 columns):
# id                      367 non-null int64
# sound_number            367 non-null int64
# sound_valence_mean      367 non-null float64
# sound_arousal_mean      367 non-null float64
# is_sound_positive       367 non-null int64
# is_sound_obscene        367 non-null int64
# picture_number          367 non-null int64
# picture_arousal_mean    367 non-null float64
# picture_valence_mean    367 non-null float64
# is_picture_positive     367 non-null int64
# is_picture_obscene      367 non-null int64
# not_processed_answer    367 non-null object
# answer_valence          367 non-null float64
# answer_arousal          367 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 40.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
# id                      400 non-null int64
# sound_number            400 non-null int64
# sound_valence_mean      400 non-null float64
# sound_arousal_mean      400 non-null float64
# is_sound_positive       400 non-null int64
# is_sound_obscene        400 non-null int64
# picture_number          400 non-null int64
# picture_arousal_mean    400 non-null float64
# picture_valence_mean    400 non-null float64
# is_picture_positive     400 non-null int64
# is_picture_obscene      400 non-null int64
# not_processed_answer    400 non-null object
# answer_valence          400 non-null float64
# answer_arousal          400 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 43.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 14 columns):
# id                      432 non-null int64
# sound_number            432 non-null int64
# sound_valence_mean      432 non-null float64
# sound_arousal_mean      432 non-null float64
# is_sound_positive       432 non-null int64
# is_sound_obscene        432 non-null int64
# picture_number          432 non-null int64
# picture_arousal_mean    432 non-null float64
# picture_valence_mean    432 non-null float64
# is_picture_positive     432 non-null int64
# is_picture_obscene      432 non-null int64
# not_processed_answer    432 non-null object
# answer_valence          432 non-null float64
# answer_arousal          432 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 47.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 14 columns):
# id                      458 non-null int64
# sound_number            458 non-null int64
# sound_valence_mean      458 non-null float64
# sound_arousal_mean      458 non-null float64
# is_sound_positive       458 non-null int64
# is_sound_obscene        458 non-null int64
# picture_number          458 non-null int64
# picture_arousal_mean    458 non-null float64
# picture_valence_mean    458 non-null float64
# is_picture_positive     458 non-null int64
# is_picture_obscene      458 non-null int64
# not_processed_answer    458 non-null object
# answer_valence          458 non-null float64
# answer_arousal          458 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 50.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 14 columns):
# id                      494 non-null int64
# sound_number            494 non-null int64
# sound_valence_mean      494 non-null float64
# sound_arousal_mean      494 non-null float64
# is_sound_positive       494 non-null int64
# is_sound_obscene        494 non-null int64
# picture_number          494 non-null int64
# picture_arousal_mean    494 non-null float64
# picture_valence_mean    494 non-null float64
# is_picture_positive     494 non-null int64
# is_picture_obscene      494 non-null int64
# not_processed_answer    494 non-null object
# answer_valence          494 non-null float64
# answer_arousal          494 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 54.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 14 columns):
# id                      520 non-null int64
# sound_number            520 non-null int64
# sound_valence_mean      520 non-null float64
# sound_arousal_mean      520 non-null float64
# is_sound_positive       520 non-null int64
# is_sound_obscene        520 non-null int64
# picture_number          520 non-null int64
# picture_arousal_mean    520 non-null float64
# picture_valence_mean    520 non-null float64
# is_picture_positive     520 non-null int64
# is_picture_obscene      520 non-null int64
# not_processed_answer    520 non-null object
# answer_valence          520 non-null float64
# answer_arousal          520 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 57.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552 entries, 0 to 551
# Data columns (total 14 columns):
# id                      552 non-null int64
# sound_number            552 non-null int64
# sound_valence_mean      552 non-null float64
# sound_arousal_mean      552 non-null float64
# is_sound_positive       552 non-null int64
# is_sound_obscene        552 non-null int64
# picture_number          552 non-null int64
# picture_arousal_mean    552 non-null float64
# picture_valence_mean    552 non-null float64
# is_picture_positive     552 non-null int64
# is_picture_obscene      552 non-null int64
# not_processed_answer    552 non-null object
# answer_valence          552 non-null float64
# answer_arousal          552 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 60.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 14 columns):
# id                      582 non-null int64
# sound_number            582 non-null int64
# sound_valence_mean      582 non-null float64
# sound_arousal_mean      582 non-null float64
# is_sound_positive       582 non-null int64
# is_sound_obscene        582 non-null int64
# picture_number          582 non-null int64
# picture_arousal_mean    582 non-null float64
# picture_valence_mean    582 non-null float64
# is_picture_positive     582 non-null int64
# is_picture_obscene      582 non-null int64
# not_processed_answer    582 non-null object
# answer_valence          582 non-null float64
# answer_arousal          582 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 63.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 14 columns):
# id                      611 non-null int64
# sound_number            611 non-null int64
# sound_valence_mean      611 non-null float64
# sound_arousal_mean      611 non-null float64
# is_sound_positive       611 non-null int64
# is_sound_obscene        611 non-null int64
# picture_number          611 non-null int64
# picture_arousal_mean    611 non-null float64
# picture_valence_mean    611 non-null float64
# is_picture_positive     611 non-null int64
# is_picture_obscene      611 non-null int64
# not_processed_answer    611 non-null object
# answer_valence          611 non-null float64
# answer_arousal          611 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 66.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 14 columns):
# id                      643 non-null int64
# sound_number            643 non-null int64
# sound_valence_mean      643 non-null float64
# sound_arousal_mean      643 non-null float64
# is_sound_positive       643 non-null int64
# is_sound_obscene        643 non-null int64
# picture_number          643 non-null int64
# picture_arousal_mean    643 non-null float64
# picture_valence_mean    643 non-null float64
# is_picture_positive     643 non-null int64
# is_picture_obscene      643 non-null int64
# not_processed_answer    643 non-null object
# answer_valence          643 non-null float64
# answer_arousal          643 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 70.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 14 columns):
# id                      675 non-null int64
# sound_number            675 non-null int64
# sound_valence_mean      675 non-null float64
# sound_arousal_mean      675 non-null float64
# is_sound_positive       675 non-null int64
# is_sound_obscene        675 non-null int64
# picture_number          675 non-null int64
# picture_arousal_mean    675 non-null float64
# picture_valence_mean    675 non-null float64
# is_picture_positive     675 non-null int64
# is_picture_obscene      675 non-null int64
# not_processed_answer    675 non-null object
# answer_valence          675 non-null float64
# answer_arousal          675 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 73.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 14 columns):
# id                      708 non-null int64
# sound_number            708 non-null int64
# sound_valence_mean      708 non-null float64
# sound_arousal_mean      708 non-null float64
# is_sound_positive       708 non-null int64
# is_sound_obscene        708 non-null int64
# picture_number          708 non-null int64
# picture_arousal_mean    708 non-null float64
# picture_valence_mean    708 non-null float64
# is_picture_positive     708 non-null int64
# is_picture_obscene      708 non-null int64
# not_processed_answer    708 non-null object
# answer_valence          708 non-null float64
# answer_arousal          708 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 77.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 14 columns):
# id                      742 non-null int64
# sound_number            742 non-null int64
# sound_valence_mean      742 non-null float64
# sound_arousal_mean      742 non-null float64
# is_sound_positive       742 non-null int64
# is_sound_obscene        742 non-null int64
# picture_number          742 non-null int64
# picture_arousal_mean    742 non-null float64
# picture_valence_mean    742 non-null float64
# is_picture_positive     742 non-null int64
# is_picture_obscene      742 non-null int64
# not_processed_answer    742 non-null object
# answer_valence          742 non-null float64
# answer_arousal          742 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 81.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 773 entries, 0 to 772
# Data columns (total 14 columns):
# id                      773 non-null int64
# sound_number            773 non-null int64
# sound_valence_mean      773 non-null float64
# sound_arousal_mean      773 non-null float64
# is_sound_positive       773 non-null int64
# is_sound_obscene        773 non-null int64
# picture_number          773 non-null int64
# picture_arousal_mean    773 non-null float64
# picture_valence_mean    773 non-null float64
# is_picture_positive     773 non-null int64
# is_picture_obscene      773 non-null int64
# not_processed_answer    773 non-null object
# answer_valence          773 non-null float64
# answer_arousal          773 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 84.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 14 columns):
# id                      801 non-null int64
# sound_number            801 non-null int64
# sound_valence_mean      801 non-null float64
# sound_arousal_mean      801 non-null float64
# is_sound_positive       801 non-null int64
# is_sound_obscene        801 non-null int64
# picture_number          801 non-null int64
# picture_arousal_mean    801 non-null float64
# picture_valence_mean    801 non-null float64
# is_picture_positive     801 non-null int64
# is_picture_obscene      801 non-null int64
# not_processed_answer    801 non-null object
# answer_valence          801 non-null float64
# answer_arousal          801 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 87.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 834 entries, 0 to 833
# Data columns (total 14 columns):
# id                      834 non-null int64
# sound_number            834 non-null int64
# sound_valence_mean      834 non-null float64
# sound_arousal_mean      834 non-null float64
# is_sound_positive       834 non-null int64
# is_sound_obscene        834 non-null int64
# picture_number          834 non-null int64
# picture_arousal_mean    834 non-null float64
# picture_valence_mean    834 non-null float64
# is_picture_positive     834 non-null int64
# is_picture_obscene      834 non-null int64
# not_processed_answer    834 non-null object
# answer_valence          834 non-null float64
# answer_arousal          834 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 91.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867 entries, 0 to 866
# Data columns (total 14 columns):
# id                      867 non-null int64
# sound_number            867 non-null int64
# sound_valence_mean      867 non-null float64
# sound_arousal_mean      867 non-null float64
# is_sound_positive       867 non-null int64
# is_sound_obscene        867 non-null int64
# picture_number          867 non-null int64
# picture_arousal_mean    867 non-null float64
# picture_valence_mean    867 non-null float64
# is_picture_positive     867 non-null int64
# is_picture_obscene      867 non-null int64
# not_processed_answer    867 non-null object
# answer_valence          867 non-null float64
# answer_arousal          867 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 94.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 14 columns):
# id                      896 non-null int64
# sound_number            896 non-null int64
# sound_valence_mean      896 non-null float64
# sound_arousal_mean      896 non-null float64
# is_sound_positive       896 non-null int64
# is_sound_obscene        896 non-null int64
# picture_number          896 non-null int64
# picture_arousal_mean    896 non-null float64
# picture_valence_mean    896 non-null float64
# is_picture_positive     896 non-null int64
# is_picture_obscene      896 non-null int64
# not_processed_answer    896 non-null object
# answer_valence          896 non-null float64
# answer_arousal          896 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 98.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 14 columns):
# id                      928 non-null int64
# sound_number            928 non-null int64
# sound_valence_mean      928 non-null float64
# sound_arousal_mean      928 non-null float64
# is_sound_positive       928 non-null int64
# is_sound_obscene        928 non-null int64
# picture_number          928 non-null int64
# picture_arousal_mean    928 non-null float64
# picture_valence_mean    928 non-null float64
# is_picture_positive     928 non-null int64
# is_picture_obscene      928 non-null int64
# not_processed_answer    928 non-null object
# answer_valence          928 non-null float64
# answer_arousal          928 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 101.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 959 entries, 0 to 958
# Data columns (total 14 columns):
# id                      959 non-null int64
# sound_number            959 non-null int64
# sound_valence_mean      959 non-null float64
# sound_arousal_mean      959 non-null float64
# is_sound_positive       959 non-null int64
# is_sound_obscene        959 non-null int64
# picture_number          959 non-null int64
# picture_arousal_mean    959 non-null float64
# picture_valence_mean    959 non-null float64
# is_picture_positive     959 non-null int64
# is_picture_obscene      959 non-null int64
# not_processed_answer    959 non-null object
# answer_valence          959 non-null float64
# answer_arousal          959 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 105.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 14 columns):
# id                      990 non-null int64
# sound_number            990 non-null int64
# sound_valence_mean      990 non-null float64
# sound_arousal_mean      990 non-null float64
# is_sound_positive       990 non-null int64
# is_sound_obscene        990 non-null int64
# picture_number          990 non-null int64
# picture_arousal_mean    990 non-null float64
# picture_valence_mean    990 non-null float64
# is_picture_positive     990 non-null int64
# is_picture_obscene      990 non-null int64
# not_processed_answer    990 non-null object
# answer_valence          990 non-null float64
# answer_arousal          990 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 108.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 14 columns):
# id                      1020 non-null int64
# sound_number            1020 non-null int64
# sound_valence_mean      1020 non-null float64
# sound_arousal_mean      1020 non-null float64
# is_sound_positive       1020 non-null int64
# is_sound_obscene        1020 non-null int64
# picture_number          1020 non-null int64
# picture_arousal_mean    1020 non-null float64
# picture_valence_mean    1020 non-null float64
# is_picture_positive     1020 non-null int64
# is_picture_obscene      1020 non-null int64
# not_processed_answer    1020 non-null object
# answer_valence          1020 non-null float64
# answer_arousal          1020 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 111.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1049 entries, 0 to 1048
# Data columns (total 14 columns):
# id                      1049 non-null int64
# sound_number            1049 non-null int64
# sound_valence_mean      1049 non-null float64
# sound_arousal_mean      1049 non-null float64
# is_sound_positive       1049 non-null int64
# is_sound_obscene        1049 non-null int64
# picture_number          1049 non-null int64
# picture_arousal_mean    1049 non-null float64
# picture_valence_mean    1049 non-null float64
# is_picture_positive     1049 non-null int64
# is_picture_obscene      1049 non-null int64
# not_processed_answer    1049 non-null object
# answer_valence          1049 non-null float64
# answer_arousal          1049 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 114.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 14 columns):
# id                      1078 non-null int64
# sound_number            1078 non-null int64
# sound_valence_mean      1078 non-null float64
# sound_arousal_mean      1078 non-null float64
# is_sound_positive       1078 non-null int64
# is_sound_obscene        1078 non-null int64
# picture_number          1078 non-null int64
# picture_arousal_mean    1078 non-null float64
# picture_valence_mean    1078 non-null float64
# is_picture_positive     1078 non-null int64
# is_picture_obscene      1078 non-null int64
# not_processed_answer    1078 non-null object
# answer_valence          1078 non-null float64
# answer_arousal          1078 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 118.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1109 entries, 0 to 1108
# Data columns (total 14 columns):
# id                      1109 non-null int64
# sound_number            1109 non-null int64
# sound_valence_mean      1109 non-null float64
# sound_arousal_mean      1109 non-null float64
# is_sound_positive       1109 non-null int64
# is_sound_obscene        1109 non-null int64
# picture_number          1109 non-null int64
# picture_arousal_mean    1109 non-null float64
# picture_valence_mean    1109 non-null float64
# is_picture_positive     1109 non-null int64
# is_picture_obscene      1109 non-null int64
# not_processed_answer    1109 non-null object
# answer_valence          1109 non-null float64
# answer_arousal          1109 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 121.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 14 columns):
# id                      1142 non-null int64
# sound_number            1142 non-null int64
# sound_valence_mean      1142 non-null float64
# sound_arousal_mean      1142 non-null float64
# is_sound_positive       1142 non-null int64
# is_sound_obscene        1142 non-null int64
# picture_number          1142 non-null int64
# picture_arousal_mean    1142 non-null float64
# picture_valence_mean    1142 non-null float64
# is_picture_positive     1142 non-null int64
# is_picture_obscene      1142 non-null int64
# not_processed_answer    1142 non-null object
# answer_valence          1142 non-null float64
# answer_arousal          1142 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 125.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1178 entries, 0 to 1177
# Data columns (total 14 columns):
# id                      1178 non-null int64
# sound_number            1178 non-null int64
# sound_valence_mean      1178 non-null float64
# sound_arousal_mean      1178 non-null float64
# is_sound_positive       1178 non-null int64
# is_sound_obscene        1178 non-null int64
# picture_number          1178 non-null int64
# picture_arousal_mean    1178 non-null float64
# picture_valence_mean    1178 non-null float64
# is_picture_positive     1178 non-null int64
# is_picture_obscene      1178 non-null int64
# not_processed_answer    1178 non-null object
# answer_valence          1178 non-null float64
# answer_arousal          1178 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 128.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 14 columns):
# id                      1205 non-null int64
# sound_number            1205 non-null int64
# sound_valence_mean      1205 non-null float64
# sound_arousal_mean      1205 non-null float64
# is_sound_positive       1205 non-null int64
# is_sound_obscene        1205 non-null int64
# picture_number          1205 non-null int64
# picture_arousal_mean    1205 non-null float64
# picture_valence_mean    1205 non-null float64
# is_picture_positive     1205 non-null int64
# is_picture_obscene      1205 non-null int64
# not_processed_answer    1205 non-null object
# answer_valence          1205 non-null float64
# answer_arousal          1205 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 131.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 14 columns):
# id                      1235 non-null int64
# sound_number            1235 non-null int64
# sound_valence_mean      1235 non-null float64
# sound_arousal_mean      1235 non-null float64
# is_sound_positive       1235 non-null int64
# is_sound_obscene        1235 non-null int64
# picture_number          1235 non-null int64
# picture_arousal_mean    1235 non-null float64
# picture_valence_mean    1235 non-null float64
# is_picture_positive     1235 non-null int64
# is_picture_obscene      1235 non-null int64
# not_processed_answer    1235 non-null object
# answer_valence          1235 non-null float64
# answer_arousal          1235 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 135.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 14 columns):
# id                      1266 non-null int64
# sound_number            1266 non-null int64
# sound_valence_mean      1266 non-null float64
# sound_arousal_mean      1266 non-null float64
# is_sound_positive       1266 non-null int64
# is_sound_obscene        1266 non-null int64
# picture_number          1266 non-null int64
# picture_arousal_mean    1266 non-null float64
# picture_valence_mean    1266 non-null float64
# is_picture_positive     1266 non-null int64
# is_picture_obscene      1266 non-null int64
# not_processed_answer    1266 non-null object
# answer_valence          1266 non-null float64
# answer_arousal          1266 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 138.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 14 columns):
# id                      1293 non-null int64
# sound_number            1293 non-null int64
# sound_valence_mean      1293 non-null float64
# sound_arousal_mean      1293 non-null float64
# is_sound_positive       1293 non-null int64
# is_sound_obscene        1293 non-null int64
# picture_number          1293 non-null int64
# picture_arousal_mean    1293 non-null float64
# picture_valence_mean    1293 non-null float64
# is_picture_positive     1293 non-null int64
# is_picture_obscene      1293 non-null int64
# not_processed_answer    1293 non-null object
# answer_valence          1293 non-null float64
# answer_arousal          1293 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 141.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1321 entries, 0 to 1320
# Data columns (total 14 columns):
# id                      1321 non-null int64
# sound_number            1321 non-null int64
# sound_valence_mean      1321 non-null float64
# sound_arousal_mean      1321 non-null float64
# is_sound_positive       1321 non-null int64
# is_sound_obscene        1321 non-null int64
# picture_number          1321 non-null int64
# picture_arousal_mean    1321 non-null float64
# picture_valence_mean    1321 non-null float64
# is_picture_positive     1321 non-null int64
# is_picture_obscene      1321 non-null int64
# not_processed_answer    1321 non-null object
# answer_valence          1321 non-null float64
# answer_arousal          1321 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 144.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 14 columns):
# id                      1350 non-null int64
# sound_number            1350 non-null int64
# sound_valence_mean      1350 non-null float64
# sound_arousal_mean      1350 non-null float64
# is_sound_positive       1350 non-null int64
# is_sound_obscene        1350 non-null int64
# picture_number          1350 non-null int64
# picture_arousal_mean    1350 non-null float64
# picture_valence_mean    1350 non-null float64
# is_picture_positive     1350 non-null int64
# is_picture_obscene      1350 non-null int64
# not_processed_answer    1350 non-null object
# answer_valence          1350 non-null float64
# answer_arousal          1350 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 147.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382 entries, 0 to 1381
# Data columns (total 14 columns):
# id                      1382 non-null int64
# sound_number            1382 non-null int64
# sound_valence_mean      1382 non-null float64
# sound_arousal_mean      1382 non-null float64
# is_sound_positive       1382 non-null int64
# is_sound_obscene        1382 non-null int64
# picture_number          1382 non-null int64
# picture_arousal_mean    1382 non-null float64
# picture_valence_mean    1382 non-null float64
# is_picture_positive     1382 non-null int64
# is_picture_obscene      1382 non-null int64
# not_processed_answer    1382 non-null object
# answer_valence          1382 non-null float64
# answer_arousal          1382 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 151.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1412 entries, 0 to 1411
# Data columns (total 14 columns):
# id                      1412 non-null int64
# sound_number            1412 non-null int64
# sound_valence_mean      1412 non-null float64
# sound_arousal_mean      1412 non-null float64
# is_sound_positive       1412 non-null int64
# is_sound_obscene        1412 non-null int64
# picture_number          1412 non-null int64
# picture_arousal_mean    1412 non-null float64
# picture_valence_mean    1412 non-null float64
# is_picture_positive     1412 non-null int64
# is_picture_obscene      1412 non-null int64
# not_processed_answer    1412 non-null object
# answer_valence          1412 non-null float64
# answer_arousal          1412 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 154.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 14 columns):
# id                      1445 non-null int64
# sound_number            1445 non-null int64
# sound_valence_mean      1445 non-null float64
# sound_arousal_mean      1445 non-null float64
# is_sound_positive       1445 non-null int64
# is_sound_obscene        1445 non-null int64
# picture_number          1445 non-null int64
# picture_arousal_mean    1445 non-null float64
# picture_valence_mean    1445 non-null float64
# is_picture_positive     1445 non-null int64
# is_picture_obscene      1445 non-null int64
# not_processed_answer    1445 non-null object
# answer_valence          1445 non-null float64
# answer_arousal          1445 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 158.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1473 entries, 0 to 1472
# Data columns (total 14 columns):
# id                      1473 non-null int64
# sound_number            1473 non-null int64
# sound_valence_mean      1473 non-null float64
# sound_arousal_mean      1473 non-null float64
# is_sound_positive       1473 non-null int64
# is_sound_obscene        1473 non-null int64
# picture_number          1473 non-null int64
# picture_arousal_mean    1473 non-null float64
# picture_valence_mean    1473 non-null float64
# is_picture_positive     1473 non-null int64
# is_picture_obscene      1473 non-null int64
# not_processed_answer    1473 non-null object
# answer_valence          1473 non-null float64
# answer_arousal          1473 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 161.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 14 columns):
# id                      1499 non-null int64
# sound_number            1499 non-null int64
# sound_valence_mean      1499 non-null float64
# sound_arousal_mean      1499 non-null float64
# is_sound_positive       1499 non-null int64
# is_sound_obscene        1499 non-null int64
# picture_number          1499 non-null int64
# picture_arousal_mean    1499 non-null float64
# picture_valence_mean    1499 non-null float64
# is_picture_positive     1499 non-null int64
# is_picture_obscene      1499 non-null int64
# not_processed_answer    1499 non-null object
# answer_valence          1499 non-null float64
# answer_arousal          1499 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 164.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1526 entries, 0 to 1525
# Data columns (total 14 columns):
# id                      1526 non-null int64
# sound_number            1526 non-null int64
# sound_valence_mean      1526 non-null float64
# sound_arousal_mean      1526 non-null float64
# is_sound_positive       1526 non-null int64
# is_sound_obscene        1526 non-null int64
# picture_number          1526 non-null int64
# picture_arousal_mean    1526 non-null float64
# picture_valence_mean    1526 non-null float64
# is_picture_positive     1526 non-null int64
# is_picture_obscene      1526 non-null int64
# not_processed_answer    1526 non-null object
# answer_valence          1526 non-null float64
# answer_arousal          1526 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 167.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 14 columns):
# id                      1559 non-null int64
# sound_number            1559 non-null int64
# sound_valence_mean      1559 non-null float64
# sound_arousal_mean      1559 non-null float64
# is_sound_positive       1559 non-null int64
# is_sound_obscene        1559 non-null int64
# picture_number          1559 non-null int64
# picture_arousal_mean    1559 non-null float64
# picture_valence_mean    1559 non-null float64
# is_picture_positive     1559 non-null int64
# is_picture_obscene      1559 non-null int64
# not_processed_answer    1559 non-null object
# answer_valence          1559 non-null float64
# answer_arousal          1559 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 170.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 14 columns):
# id                      1592 non-null int64
# sound_number            1592 non-null int64
# sound_valence_mean      1592 non-null float64
# sound_arousal_mean      1592 non-null float64
# is_sound_positive       1592 non-null int64
# is_sound_obscene        1592 non-null int64
# picture_number          1592 non-null int64
# picture_arousal_mean    1592 non-null float64
# picture_valence_mean    1592 non-null float64
# is_picture_positive     1592 non-null int64
# is_picture_obscene      1592 non-null int64
# not_processed_answer    1592 non-null object
# answer_valence          1592 non-null float64
# answer_arousal          1592 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 174.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1621 entries, 0 to 1620
# Data columns (total 14 columns):
# id                      1621 non-null int64
# sound_number            1621 non-null int64
# sound_valence_mean      1621 non-null float64
# sound_arousal_mean      1621 non-null float64
# is_sound_positive       1621 non-null int64
# is_sound_obscene        1621 non-null int64
# picture_number          1621 non-null int64
# picture_arousal_mean    1621 non-null float64
# picture_valence_mean    1621 non-null float64
# is_picture_positive     1621 non-null int64
# is_picture_obscene      1621 non-null int64
# not_processed_answer    1621 non-null object
# answer_valence          1621 non-null float64
# answer_arousal          1621 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 177.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1650 entries, 0 to 1649
# Data columns (total 14 columns):
# id                      1650 non-null int64
# sound_number            1650 non-null int64
# sound_valence_mean      1650 non-null float64
# sound_arousal_mean      1650 non-null float64
# is_sound_positive       1650 non-null int64
# is_sound_obscene        1650 non-null int64
# picture_number          1650 non-null int64
# picture_arousal_mean    1650 non-null float64
# picture_valence_mean    1650 non-null float64
# is_picture_positive     1650 non-null int64
# is_picture_obscene      1650 non-null int64
# not_processed_answer    1650 non-null object
# answer_valence          1650 non-null float64
# answer_arousal          1650 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 180.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1676 entries, 0 to 1675
# Data columns (total 14 columns):
# id                      1676 non-null int64
# sound_number            1676 non-null int64
# sound_valence_mean      1676 non-null float64
# sound_arousal_mean      1676 non-null float64
# is_sound_positive       1676 non-null int64
# is_sound_obscene        1676 non-null int64
# picture_number          1676 non-null int64
# picture_arousal_mean    1676 non-null float64
# picture_valence_mean    1676 non-null float64
# is_picture_positive     1676 non-null int64
# is_picture_obscene      1676 non-null int64
# not_processed_answer    1676 non-null object
# answer_valence          1676 non-null float64
# answer_arousal          1676 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 183.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711 entries, 0 to 1710
# Data columns (total 14 columns):
# id                      1711 non-null int64
# sound_number            1711 non-null int64
# sound_valence_mean      1711 non-null float64
# sound_arousal_mean      1711 non-null float64
# is_sound_positive       1711 non-null int64
# is_sound_obscene        1711 non-null int64
# picture_number          1711 non-null int64
# picture_arousal_mean    1711 non-null float64
# picture_valence_mean    1711 non-null float64
# is_picture_positive     1711 non-null int64
# is_picture_obscene      1711 non-null int64
# not_processed_answer    1711 non-null object
# answer_valence          1711 non-null float64
# answer_arousal          1711 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 187.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1739 entries, 0 to 1738
# Data columns (total 14 columns):
# id                      1739 non-null int64
# sound_number            1739 non-null int64
# sound_valence_mean      1739 non-null float64
# sound_arousal_mean      1739 non-null float64
# is_sound_positive       1739 non-null int64
# is_sound_obscene        1739 non-null int64
# picture_number          1739 non-null int64
# picture_arousal_mean    1739 non-null float64
# picture_valence_mean    1739 non-null float64
# is_picture_positive     1739 non-null int64
# is_picture_obscene      1739 non-null int64
# not_processed_answer    1739 non-null object
# answer_valence          1739 non-null float64
# answer_arousal          1739 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 190.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1768 entries, 0 to 1767
# Data columns (total 14 columns):
# id                      1768 non-null int64
# sound_number            1768 non-null int64
# sound_valence_mean      1768 non-null float64
# sound_arousal_mean      1768 non-null float64
# is_sound_positive       1768 non-null int64
# is_sound_obscene        1768 non-null int64
# picture_number          1768 non-null int64
# picture_arousal_mean    1768 non-null float64
# picture_valence_mean    1768 non-null float64
# is_picture_positive     1768 non-null int64
# is_picture_obscene      1768 non-null int64
# not_processed_answer    1768 non-null object
# answer_valence          1768 non-null float64
# answer_arousal          1768 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 193.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1799 entries, 0 to 1798
# Data columns (total 14 columns):
# id                      1799 non-null int64
# sound_number            1799 non-null int64
# sound_valence_mean      1799 non-null float64
# sound_arousal_mean      1799 non-null float64
# is_sound_positive       1799 non-null int64
# is_sound_obscene        1799 non-null int64
# picture_number          1799 non-null int64
# picture_arousal_mean    1799 non-null float64
# picture_valence_mean    1799 non-null float64
# is_picture_positive     1799 non-null int64
# is_picture_obscene      1799 non-null int64
# not_processed_answer    1799 non-null object
# answer_valence          1799 non-null float64
# answer_arousal          1799 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 196.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832 entries, 0 to 1831
# Data columns (total 14 columns):
# id                      1832 non-null int64
# sound_number            1832 non-null int64
# sound_valence_mean      1832 non-null float64
# sound_arousal_mean      1832 non-null float64
# is_sound_positive       1832 non-null int64
# is_sound_obscene        1832 non-null int64
# picture_number          1832 non-null int64
# picture_arousal_mean    1832 non-null float64
# picture_valence_mean    1832 non-null float64
# is_picture_positive     1832 non-null int64
# is_picture_obscene      1832 non-null int64
# not_processed_answer    1832 non-null object
# answer_valence          1832 non-null float64
# answer_arousal          1832 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 200.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 14 columns):
# id                      1865 non-null int64
# sound_number            1865 non-null int64
# sound_valence_mean      1865 non-null float64
# sound_arousal_mean      1865 non-null float64
# is_sound_positive       1865 non-null int64
# is_sound_obscene        1865 non-null int64
# picture_number          1865 non-null int64
# picture_arousal_mean    1865 non-null float64
# picture_valence_mean    1865 non-null float64
# is_picture_positive     1865 non-null int64
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188 entries, 0 to 2187
# Data columns (total 14 columns):
# id                      2188 non-null int64
# sound_number            2188 non-null int64
# sound_valence_mean      2188 non-null float64
# sound_arousal_mean      2188 non-null float64
# is_sound_positive       2188 non-null int64
# is_sound_obscene        2188 non-null int64
# picture_number          2188 non-null int64
# picture_arousal_mean    2188 non-null float64
# picture_valence_mean    2188 non-null float64
# is_picture_positive     2188 non-null int64
# is_picture_obscene      2188 non-null int64
# not_processed_answer    2188 non-null object
# answer_valence          2188 non-null float64
# answer_arousal          2188 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 239.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216 entries, 0 to 2215
# Data columns (total 14 columns):
# id                      2216 non-null int64
# sound_number            2216 non-null int64
# sound_valence_mean      2216 non-null float64
# sound_arousal_mean      2216 non-null float64
# is_sound_positive       2216 non-null int64
# is_sound_obscene        2216 non-null int64
# picture_number          2216 non-null int64
# picture_arousal_mean    2216 non-null float64
# picture_valence_mean    2216 non-null float64
# is_picture_positive     2216 non-null int64
# is_picture_obscene      2216 non-null int64
# not_processed_answer    2216 non-null object
# answer_valence          2216 non-null float64
# answer_arousal          2216 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 242.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2247 entries, 0 to 2246
# Data columns (total 14 columns):
# id                      2247 non-null int64
# sound_number            2247 non-null int64
# sound_valence_mean      2247 non-null float64
# sound_arousal_mean      2247 non-null float64
# is_sound_positive       2247 non-null int64
# is_sound_obscene        2247 non-null int64
# picture_number          2247 non-null int64
# picture_arousal_mean    2247 non-null float64
# picture_valence_mean    2247 non-null float64
# is_picture_positive     2247 non-null int64
# is_picture_obscene      2247 non-null int64
# not_processed_answer    2247 non-null object
# answer_valence          2247 non-null float64
# answer_arousal          2247 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 245.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2272 entries, 0 to 2271
# Data columns (total 14 columns):
# id                      2272 non-null int64
# sound_number            2272 non-null int64
# sound_valence_mean      2272 non-null float64
# sound_arousal_mean      2272 non-null float64
# is_sound_positive       2272 non-null int64
# is_sound_obscene        2272 non-null int64
# picture_number          2272 non-null int64
# picture_arousal_mean    2272 non-null float64
# picture_valence_mean    2272 non-null float64
# is_picture_positive     2272 non-null int64
# is_picture_obscene      2272 non-null int64
# not_processed_answer    2272 non-null object
# answer_valence          2272 non-null float64
# answer_arousal          2272 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 248.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2301 entries, 0 to 2300
# Data columns (total 14 columns):
# id                      2301 non-null int64
# sound_number            2301 non-null int64
# sound_valence_mean      2301 non-null float64
# sound_arousal_mean      2301 non-null float64
# is_sound_positive       2301 non-null int64
# is_sound_obscene        2301 non-null int64
# picture_number          2301 non-null int64
# picture_arousal_mean    2301 non-null float64
# picture_valence_mean    2301 non-null float64
# is_picture_positive     2301 non-null int64
# is_picture_obscene      2301 non-null int64
# not_processed_answer    2301 non-null object
# answer_valence          2301 non-null float64
# answer_arousal          2301 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 251.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 14 columns):
# id                      2331 non-null int64
# sound_number            2331 non-null int64
# sound_valence_mean      2331 non-null float64
# sound_arousal_mean      2331 non-null float64
# is_sound_positive       2331 non-null int64
# is_sound_obscene        2331 non-null int64
# picture_number          2331 non-null int64
# picture_arousal_mean    2331 non-null float64
# picture_valence_mean    2331 non-null float64
# is_picture_positive     2331 non-null int64
# is_picture_obscene      2331 non-null int64
# not_processed_answer    2331 non-null object
# answer_valence          2331 non-null float64
# answer_arousal          2331 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 255.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2362 entries, 0 to 2361
# Data columns (total 14 columns):
# id                      2362 non-null int64
# sound_number            2362 non-null int64
# sound_valence_mean      2362 non-null float64
# sound_arousal_mean      2362 non-null float64
# is_sound_positive       2362 non-null int64
# is_sound_obscene        2362 non-null int64
# picture_number          2362 non-null int64
# picture_arousal_mean    2362 non-null float64
# picture_valence_mean    2362 non-null float64
# is_picture_positive     2362 non-null int64
# is_picture_obscene      2362 non-null int64
# not_processed_answer    2362 non-null object
# answer_valence          2362 non-null float64
# answer_arousal          2362 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 258.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2387 entries, 0 to 2386
# Data columns (total 14 columns):
# id                      2387 non-null int64
# sound_number            2387 non-null int64
# sound_valence_mean      2387 non-null float64
# sound_arousal_mean      2387 non-null float64
# is_sound_positive       2387 non-null int64
# is_sound_obscene        2387 non-null int64
# picture_number          2387 non-null int64
# picture_arousal_mean    2387 non-null float64
# picture_valence_mean    2387 non-null float64
# is_picture_positive     2387 non-null int64
# is_picture_obscene      2387 non-null int64
# not_processed_answer    2387 non-null object
# answer_valence          2387 non-null float64
# answer_arousal          2387 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 261.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2419 entries, 0 to 2418
# Data columns (total 14 columns):
# id                      2419 non-null int64
# sound_number            2419 non-null int64
# sound_valence_mean      2419 non-null float64
# sound_arousal_mean      2419 non-null float64
# is_sound_positive       2419 non-null int64
# is_sound_obscene        2419 non-null int64
# picture_number          2419 non-null int64
# picture_arousal_mean    2419 non-null float64
# picture_valence_mean    2419 non-null float64
# is_picture_positive     2419 non-null int64
# is_picture_obscene      2419 non-null int64
# not_processed_answer    2419 non-null object
# answer_valence          2419 non-null float64
# answer_arousal          2419 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 264.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2448 entries, 0 to 2447
# Data columns (total 14 columns):
# id                      2448 non-null int64
# sound_number            2448 non-null int64
# sound_valence_mean      2448 non-null float64
# sound_arousal_mean      2448 non-null float64
# is_sound_positive       2448 non-null int64
# is_sound_obscene        2448 non-null int64
# picture_number          2448 non-null int64
# picture_arousal_mean    2448 non-null float64
# picture_valence_mean    2448 non-null float64
# is_picture_positive     2448 non-null int64
# is_picture_obscene      2448 non-null int64
# not_processed_answer    2448 non-null object
# answer_valence          2448 non-null float64
# answer_arousal          2448 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 267.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2481 entries, 0 to 2480
# Data columns (total 14 columns):
# id                      2481 non-null int64
# sound_number            2481 non-null int64
# sound_valence_mean      2481 non-null float64
# sound_arousal_mean      2481 non-null float64
# is_sound_positive       2481 non-null int64
# is_sound_obscene        2481 non-null int64
# picture_number          2481 non-null int64
# picture_arousal_mean    2481 non-null float64
# picture_valence_mean    2481 non-null float64
# is_picture_positive     2481 non-null int64
# is_picture_obscene      2481 non-null int64
# not_processed_answer    2481 non-null object
# answer_valence          2481 non-null float64
# answer_arousal          2481 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 271.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2506 entries, 0 to 2505
# Data columns (total 14 columns):
# id                      2506 non-null int64
# sound_number            2506 non-null int64
# sound_valence_mean      2506 non-null float64
# sound_arousal_mean      2506 non-null float64
# is_sound_positive       2506 non-null int64
# is_sound_obscene        2506 non-null int64
# picture_number          2506 non-null int64
# picture_arousal_mean    2506 non-null float64
# picture_valence_mean    2506 non-null float64
# is_picture_positive     2506 non-null int64
# is_picture_obscene      2506 non-null int64
# not_processed_answer    2506 non-null object
# answer_valence          2506 non-null float64
# answer_arousal          2506 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 274.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2534 entries, 0 to 2533
# Data columns (total 14 columns):
# id                      2534 non-null int64
# sound_number            2534 non-null int64
# sound_valence_mean      2534 non-null float64
# sound_arousal_mean      2534 non-null float64
# is_sound_positive       2534 non-null int64
# is_sound_obscene        2534 non-null int64
# picture_number          2534 non-null int64
# picture_arousal_mean    2534 non-null float64
# picture_valence_mean    2534 non-null float64
# is_picture_positive     2534 non-null int64
# is_picture_obscene      2534 non-null int64
# not_processed_answer    2534 non-null object
# answer_valence          2534 non-null float64
# answer_arousal          2534 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 277.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2565 entries, 0 to 2564
# Data columns (total 14 columns):
# id                      2565 non-null int64
# sound_number            2565 non-null int64
# sound_valence_mean      2565 non-null float64
# sound_arousal_mean      2565 non-null float64
# is_sound_positive       2565 non-null int64
# is_sound_obscene        2565 non-null int64
# picture_number          2565 non-null int64
# picture_arousal_mean    2565 non-null float64
# picture_valence_mean    2565 non-null float64
# is_picture_positive     2565 non-null int64
# is_picture_obscene      2565 non-null int64
# not_processed_answer    2565 non-null object
# answer_valence          2565 non-null float64
# answer_arousal          2565 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 280.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2599 entries, 0 to 2598
# Data columns (total 14 columns):
# id                      2599 non-null int64
# sound_number            2599 non-null int64
# sound_valence_mean      2599 non-null float64
# sound_arousal_mean      2599 non-null float64
# is_sound_positive       2599 non-null int64
# is_sound_obscene        2599 non-null int64
# picture_number          2599 non-null int64
# picture_arousal_mean    2599 non-null float64
# picture_valence_mean    2599 non-null float64
# is_picture_positive     2599 non-null int64
# is_picture_obscene      2599 non-null int64
# not_processed_answer    2599 non-null object
# answer_valence          2599 non-null float64
# answer_arousal          2599 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 284.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2629 entries, 0 to 2628
# Data columns (total 14 columns):
# id                      2629 non-null int64
# sound_number            2629 non-null int64
# sound_valence_mean      2629 non-null float64
# sound_arousal_mean      2629 non-null float64
# is_sound_positive       2629 non-null int64
# is_sound_obscene        2629 non-null int64
# picture_number          2629 non-null int64
# picture_arousal_mean    2629 non-null float64
# picture_valence_mean    2629 non-null float64
# is_picture_positive     2629 non-null int64
# is_picture_obscene      2629 non-null int64
# not_processed_answer    2629 non-null object
# answer_valence          2629 non-null float64
# answer_arousal          2629 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 287.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 14 columns):
# id                      2662 non-null int64
# sound_number            2662 non-null int64
# sound_valence_mean      2662 non-null float64
# sound_arousal_mean      2662 non-null float64
# is_sound_positive       2662 non-null int64
# is_sound_obscene        2662 non-null int64
# picture_number          2662 non-null int64
# picture_arousal_mean    2662 non-null float64
# picture_valence_mean    2662 non-null float64
# is_picture_positive     2662 non-null int64
# is_picture_obscene      2662 non-null int64
# not_processed_answer    2662 non-null object
# answer_valence          2662 non-null float64
# answer_arousal          2662 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 291.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2693 entries, 0 to 2692
# Data columns (total 14 columns):
# id                      2693 non-null int64
# sound_number            2693 non-null int64
# sound_valence_mean      2693 non-null float64
# sound_arousal_mean      2693 non-null float64
# is_sound_positive       2693 non-null int64
# is_sound_obscene        2693 non-null int64
# picture_number          2693 non-null int64
# picture_arousal_mean    2693 non-null float64
# picture_valence_mean    2693 non-null float64
# is_picture_positive     2693 non-null int64
# is_picture_obscene      2693 non-null int64
# not_processed_answer    2693 non-null object
# answer_valence          2693 non-null float64
# answer_arousal          2693 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 294.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2724 entries, 0 to 2723
# Data columns (total 14 columns):
# id                      2724 non-null int64
# sound_number            2724 non-null int64
# sound_valence_mean      2724 non-null float64
# sound_arousal_mean      2724 non-null float64
# is_sound_positive       2724 non-null int64
# is_sound_obscene        2724 non-null int64
# picture_number          2724 non-null int64
# picture_arousal_mean    2724 non-null float64
# picture_valence_mean    2724 non-null float64
# is_picture_positive     2724 non-null int64
# is_picture_obscene      2724 non-null int64
# not_processed_answer    2724 non-null object
# answer_valence          2724 non-null float64
# answer_arousal          2724 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 298.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2757 entries, 0 to 2756
# Data columns (total 14 columns):
# id                      2757 non-null int64
# sound_number            2757 non-null int64
# sound_valence_mean      2757 non-null float64
# sound_arousal_mean      2757 non-null float64
# is_sound_positive       2757 non-null int64
# is_sound_obscene        2757 non-null int64
# picture_number          2757 non-null int64
# picture_arousal_mean    2757 non-null float64
# picture_valence_mean    2757 non-null float64
# is_picture_positive     2757 non-null int64
# is_picture_obscene      2757 non-null int64
# not_processed_answer    2757 non-null object
# answer_valence          2757 non-null float64
# answer_arousal          2757 non-null float64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 301.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = df.corr()
plt.figure(figsize=(10,8))
ax = sns.heatmap(correlation_matrix, vmax=1, square=True, annot=True,fmt='.2f', cmap ='GnBu', cbar_kws={"shrink": .5}, robust=True)
plt.title('Correlation matrix between the features', fontsize=20)
plt.show()

# %%
#df = df.drop(['is_sound_positive', 'is_picture_positive', 'id'], axis=1)
print(df.columns)
all_features = ['sound_number', 'sound_valence_mean', 'sound_arousal_mean',
    'is_sound_obscene', 'picture_arousal_mean',
       'picture_valence_mean', 'picture_valence_mean', 'is_picture_positive',
       'is_picture_obscene']
target = ['answer_valence']

from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.2, random_state=2)
# Out:
# Index(['id', 'sound_number', 'sound_valence_mean', 'sound_arousal_mean',
#        'is_sound_positive', 'is_sound_obscene', 'picture_number',
#        'picture_arousal_mean', 'picture_valence_mean', 'is_picture_positive',
#        'is_picture_obscene', 'not_processed_answer', 'answer_valence',
#        'answer_arousal'],
#       dtype='object')

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
model = linear_model.LinearRegression(fit_intercept=False, normalize=True, copy_X=True, n_jobs=None) #fit intercept = false zwiekszylo

from sklearn.model_selection import cross_val_score
cv_result=cross_val_score(model, train[all_features], train[target],cv=10) 
print(cv_result.mean())

model.fit(train[all_features], train[target])
predicted = model.predict(test[all_features])

print("Mean squared error: %.2f"
      % mean_squared_error(test[target], predicted))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(test[target], predicted))
# Out:
# 0.24307172625199264
# Mean squared error: 4.32
# Variance score: 0.21

# %%
from sklearn.model_selection import GridSearchCV

def performLinearGridSearch(algo, params):
    clf = GridSearchCV(algo(), params, cv=5,
                   scoring='neg_mean_squared_error')
    clf.fit(train[all_features], train[target])

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    return clf.best_params_

# %%
def computeScore(y_test, y_pred):
    mse = mean_squared_error(y_test, y_pred)
    print("Mean squared error: %.2f"
      % mse)
    # Explained variance score: 1 is perfect prediction
    r2 = r2_score(y_test, y_pred)
    print('Variance score: %.2f' % r2)
    
    return [mse, r2]

# %%
alphas = np.logspace(-5, 2, 30)

names = ['linear regression', 'lasso', 'elastic net']
models_params = [(
    linear_model.LinearRegression, {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}), 
    (linear_model.Lasso, {'alpha': alphas, 'fit_intercept': [True, False]}), 
    (linear_model.ElasticNet, {'alpha': alphas, 'fit_intercept': [True, False], 'normalize': [True, False]})]

results = [['mean squared error', 'variance score']]

for m,p in models_params:
    bp = performLinearGridSearch(m, p)
    if m == linear_model.Lasso:
        model = linear_model.Lasso(alpha=0.000161026, fit_intercept=True)
    elif m == linear_model.ElasticNet:
        model = linear_model.ElasticNet(alpha=0.0002807, fit_intercept=True, normalize=False)
    else:
        model = m(bp)

    
    model.fit(train[all_features], train[target])
    predicted = model.predict(test[all_features])
    results.append(computeScore(test[target], predicted))
# Out:
# Best parameters set found on development set:
#
# {'copy_X': True, 'fit_intercept': True, 'normalize': False}
#
# Grid scores on development set:
#
# -4.339 (+/-0.435) for {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.420) for {'copy_X': True, 'fit_intercept': True, 'normalize': False}
# -4.359 (+/-0.427) for {'copy_X': True, 'fit_intercept': False, 'normalize': True}
# -4.359 (+/-0.427) for {'copy_X': True, 'fit_intercept': False, 'normalize': False}
# -4.339 (+/-0.435) for {'copy_X': False, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.420) for {'copy_X': False, 'fit_intercept': True, 'normalize': False}
# -4.359 (+/-0.427) for {'copy_X': False, 'fit_intercept': False, 'normalize': True}
# -4.359 (+/-0.427) for {'copy_X': False, 'fit_intercept': False, 'normalize': False}
#
# Mean squared error: 4.32
# Variance score: 0.21
# Best parameters set found on development set:
#
# {'alpha': 0.00016102620275609394, 'fit_intercept': True}
#
# Grid scores on development set:
#
# -4.333 (+/-0.419) for {'alpha': 1e-05, 'fit_intercept': True}
# -4.365 (+/-0.436) for {'alpha': 1e-05, 'fit_intercept': False}
# -4.333 (+/-0.419) for {'alpha': 1.7433288221999873e-05, 'fit_intercept': True}
# -4.365 (+/-0.436) for {'alpha': 1.7433288221999873e-05, 'fit_intercept': False}
# -4.333 (+/-0.419) for {'alpha': 3.039195382313195e-05, 'fit_intercept': True}
# -4.365 (+/-0.436) for {'alpha': 3.039195382313195e-05, 'fit_intercept': False}
# -4.333 (+/-0.419) for {'alpha': 5.2983169062837125e-05, 'fit_intercept': True}
# -4.365 (+/-0.437) for {'alpha': 5.2983169062837125e-05, 'fit_intercept': False}
# -4.333 (+/-0.419) for {'alpha': 9.236708571873866e-05, 'fit_intercept': True}
# -4.365 (+/-0.437) for {'alpha': 9.236708571873866e-05, 'fit_intercept': False}
# -4.333 (+/-0.419) for {'alpha': 0.00016102620275609394, 'fit_intercept': True}
# -4.366 (+/-0.437) for {'alpha': 0.00016102620275609394, 'fit_intercept': False}
# -4.333 (+/-0.418) for {'alpha': 0.0002807216203941176, 'fit_intercept': True}
# -4.366 (+/-0.438) for {'alpha': 0.0002807216203941176, 'fit_intercept': False}
# -4.333 (+/-0.418) for {'alpha': 0.0004893900918477494, 'fit_intercept': True}
# -4.367 (+/-0.439) for {'alpha': 0.0004893900918477494, 'fit_intercept': False}
# -4.333 (+/-0.418) for {'alpha': 0.0008531678524172815, 'fit_intercept': True}
# -4.369 (+/-0.442) for {'alpha': 0.0008531678524172815, 'fit_intercept': False}
# -4.333 (+/-0.418) for {'alpha': 0.0014873521072935117, 'fit_intercept': True}
# -4.373 (+/-0.445) for {'alpha': 0.0014873521072935117, 'fit_intercept': False}
# -4.333 (+/-0.419) for {'alpha': 0.002592943797404667, 'fit_intercept': True}
# -4.380 (+/-0.450) for {'alpha': 0.002592943797404667, 'fit_intercept': False}
# -4.334 (+/-0.420) for {'alpha': 0.004520353656360245, 'fit_intercept': True}
# -4.397 (+/-0.460) for {'alpha': 0.004520353656360245, 'fit_intercept': False}
# -4.336 (+/-0.422) for {'alpha': 0.007880462815669913, 'fit_intercept': True}
# -4.413 (+/-0.458) for {'alpha': 0.007880462815669913, 'fit_intercept': False}
# -4.342 (+/-0.426) for {'alpha': 0.013738237958832637, 'fit_intercept': True}
# -4.416 (+/-0.456) for {'alpha': 0.013738237958832637, 'fit_intercept': False}
# -4.358 (+/-0.433) for {'alpha': 0.02395026619987486, 'fit_intercept': True}
# -4.423 (+/-0.456) for {'alpha': 0.02395026619987486, 'fit_intercept': False}
# -4.379 (+/-0.447) for {'alpha': 0.04175318936560404, 'fit_intercept': True}
# -4.448 (+/-0.457) for {'alpha': 0.04175318936560404, 'fit_intercept': False}
# -4.430 (+/-0.464) for {'alpha': 0.07278953843983153, 'fit_intercept': True}
# -4.486 (+/-0.441) for {'alpha': 0.07278953843983153, 'fit_intercept': False}
# -4.468 (+/-0.444) for {'alpha': 0.12689610031679235, 'fit_intercept': True}
# -4.498 (+/-0.443) for {'alpha': 0.12689610031679235, 'fit_intercept': False}
# -4.576 (+/-0.403) for {'alpha': 0.22122162910704501, 'fit_intercept': True}
# -4.505 (+/-0.444) for {'alpha': 0.22122162910704501, 'fit_intercept': False}
# -4.757 (+/-0.345) for {'alpha': 0.38566204211634725, 'fit_intercept': True}
# -4.531 (+/-0.439) for {'alpha': 0.38566204211634725, 'fit_intercept': False}
# -4.812 (+/-0.256) for {'alpha': 0.6723357536499335, 'fit_intercept': True}
# -4.627 (+/-0.408) for {'alpha': 0.6723357536499335, 'fit_intercept': False}
# -4.979 (+/-0.179) for {'alpha': 1.1721022975334818, 'fit_intercept': True}
# -4.905 (+/-0.373) for {'alpha': 1.1721022975334818, 'fit_intercept': False}
# -5.485 (+/-0.398) for {'alpha': 2.043359717856944, 'fit_intercept': True}
# -5.295 (+/-0.369) for {'alpha': 2.043359717856944, 'fit_intercept': False}
# -5.625 (+/-0.329) for {'alpha': 3.562247890262444, 'fit_intercept': True}
# -6.332 (+/-0.544) for {'alpha': 3.562247890262444, 'fit_intercept': False}
# -5.625 (+/-0.329) for {'alpha': 6.2101694189156165, 'fit_intercept': True}
# -8.700 (+/-0.954) for {'alpha': 6.2101694189156165, 'fit_intercept': False}
# -5.627 (+/-0.329) for {'alpha': 10.82636733874054, 'fit_intercept': True}
# -8.714 (+/-0.921) for {'alpha': 10.82636733874054, 'fit_intercept': False}
# -5.632 (+/-0.330) for {'alpha': 18.873918221350994, 'fit_intercept': True}
# -8.715 (+/-0.929) for {'alpha': 18.873918221350994, 'fit_intercept': False}
# -5.648 (+/-0.332) for {'alpha': 32.90344562312671, 'fit_intercept': True}
# -8.718 (+/-0.942) for {'alpha': 32.90344562312671, 'fit_intercept': False}
# -5.696 (+/-0.339) for {'alpha': 57.361525104486816, 'fit_intercept': True}
# -8.728 (+/-0.966) for {'alpha': 57.361525104486816, 'fit_intercept': False}
# -5.786 (+/-0.344) for {'alpha': 100.0, 'fit_intercept': True}
# -8.758 (+/-1.006) for {'alpha': 100.0, 'fit_intercept': False}
#
# Mean squared error: 4.31
# Variance score: 0.22
# Best parameters set found on development set:
#
# {'alpha': 0.0002807216203941176, 'fit_intercept': True, 'normalize': False}
#
# Grid scores on development set:
#
# -4.336 (+/-0.414) for {'alpha': 1e-05, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.419) for {'alpha': 1e-05, 'fit_intercept': True, 'normalize': False}
# -4.365 (+/-0.436) for {'alpha': 1e-05, 'fit_intercept': False, 'normalize': True}
# -4.365 (+/-0.436) for {'alpha': 1e-05, 'fit_intercept': False, 'normalize': False}
# -4.340 (+/-0.411) for {'alpha': 1.7433288221999873e-05, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.419) for {'alpha': 1.7433288221999873e-05, 'fit_intercept': True, 'normalize': False}
# -4.365 (+/-0.437) for {'alpha': 1.7433288221999873e-05, 'fit_intercept': False, 'normalize': True}
# -4.365 (+/-0.437) for {'alpha': 1.7433288221999873e-05, 'fit_intercept': False, 'normalize': False}
# -4.352 (+/-0.405) for {'alpha': 3.039195382313195e-05, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.419) for {'alpha': 3.039195382313195e-05, 'fit_intercept': True, 'normalize': False}
# -4.365 (+/-0.437) for {'alpha': 3.039195382313195e-05, 'fit_intercept': False, 'normalize': True}
# -4.365 (+/-0.437) for {'alpha': 3.039195382313195e-05, 'fit_intercept': False, 'normalize': False}
# -4.378 (+/-0.395) for {'alpha': 5.2983169062837125e-05, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.419) for {'alpha': 5.2983169062837125e-05, 'fit_intercept': True, 'normalize': False}
# -4.366 (+/-0.437) for {'alpha': 5.2983169062837125e-05, 'fit_intercept': False, 'normalize': True}
# -4.366 (+/-0.437) for {'alpha': 5.2983169062837125e-05, 'fit_intercept': False, 'normalize': False}
# -4.427 (+/-0.380) for {'alpha': 9.236708571873866e-05, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.419) for {'alpha': 9.236708571873866e-05, 'fit_intercept': True, 'normalize': False}
# -4.366 (+/-0.438) for {'alpha': 9.236708571873866e-05, 'fit_intercept': False, 'normalize': True}
# -4.366 (+/-0.438) for {'alpha': 9.236708571873866e-05, 'fit_intercept': False, 'normalize': False}
# -4.502 (+/-0.357) for {'alpha': 0.00016102620275609394, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.419) for {'alpha': 0.00016102620275609394, 'fit_intercept': True, 'normalize': False}
# -4.367 (+/-0.439) for {'alpha': 0.00016102620275609394, 'fit_intercept': False, 'normalize': True}
# -4.367 (+/-0.439) for {'alpha': 0.00016102620275609394, 'fit_intercept': False, 'normalize': False}
# -4.597 (+/-0.326) for {'alpha': 0.0002807216203941176, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.418) for {'alpha': 0.0002807216203941176, 'fit_intercept': True, 'normalize': False}
# -4.368 (+/-0.441) for {'alpha': 0.0002807216203941176, 'fit_intercept': False, 'normalize': True}
# -4.368 (+/-0.441) for {'alpha': 0.0002807216203941176, 'fit_intercept': False, 'normalize': False}
# -4.699 (+/-0.290) for {'alpha': 0.0004893900918477494, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.418) for {'alpha': 0.0004893900918477494, 'fit_intercept': True, 'normalize': False}
# -4.370 (+/-0.444) for {'alpha': 0.0004893900918477494, 'fit_intercept': False, 'normalize': True}
# -4.370 (+/-0.444) for {'alpha': 0.0004893900918477494, 'fit_intercept': False, 'normalize': False}
# -4.800 (+/-0.249) for {'alpha': 0.0008531678524172815, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.418) for {'alpha': 0.0008531678524172815, 'fit_intercept': True, 'normalize': False}
# -4.374 (+/-0.448) for {'alpha': 0.0008531678524172815, 'fit_intercept': False, 'normalize': True}
# -4.374 (+/-0.448) for {'alpha': 0.0008531678524172815, 'fit_intercept': False, 'normalize': False}
# -4.901 (+/-0.202) for {'alpha': 0.0014873521072935117, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.418) for {'alpha': 0.0014873521072935117, 'fit_intercept': True, 'normalize': False}
# -4.380 (+/-0.453) for {'alpha': 0.0014873521072935117, 'fit_intercept': False, 'normalize': True}
# -4.380 (+/-0.453) for {'alpha': 0.0014873521072935117, 'fit_intercept': False, 'normalize': False}
# -5.019 (+/-0.177) for {'alpha': 0.002592943797404667, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.419) for {'alpha': 0.002592943797404667, 'fit_intercept': True, 'normalize': False}
# -4.389 (+/-0.458) for {'alpha': 0.002592943797404667, 'fit_intercept': False, 'normalize': True}
# -4.389 (+/-0.458) for {'alpha': 0.002592943797404667, 'fit_intercept': False, 'normalize': False}
# -5.177 (+/-0.193) for {'alpha': 0.004520353656360245, 'fit_intercept': True, 'normalize': True}
# -4.333 (+/-0.420) for {'alpha': 0.004520353656360245, 'fit_intercept': True, 'normalize': False}
# -4.399 (+/-0.461) for {'alpha': 0.004520353656360245, 'fit_intercept': False, 'normalize': True}
# -4.399 (+/-0.461) for {'alpha': 0.004520353656360245, 'fit_intercept': False, 'normalize': False}
# -5.361 (+/-0.241) for {'alpha': 0.007880462815669913, 'fit_intercept': True, 'normalize': True}
# -4.334 (+/-0.421) for {'alpha': 0.007880462815669913, 'fit_intercept': True, 'normalize': False}
# -4.408 (+/-0.462) for {'alpha': 0.007880462815669913, 'fit_intercept': False, 'normalize': True}
# -4.408 (+/-0.462) for {'alpha': 0.007880462815669913, 'fit_intercept': False, 'normalize': False}
# -5.544 (+/-0.293) for {'alpha': 0.013738237958832637, 'fit_intercept': True, 'normalize': True}
# -4.337 (+/-0.423) for {'alpha': 0.013738237958832637, 'fit_intercept': True, 'normalize': False}
# -4.414 (+/-0.460) for {'alpha': 0.013738237958832637, 'fit_intercept': False, 'normalize': True}
# -4.414 (+/-0.460) for {'alpha': 0.013738237958832637, 'fit_intercept': False, 'normalize': False}
# -5.692 (+/-0.331) for {'alpha': 0.02395026619987486, 'fit_intercept': True, 'normalize': True}
# -4.344 (+/-0.427) for {'alpha': 0.02395026619987486, 'fit_intercept': True, 'normalize': False}
# -4.418 (+/-0.458) for {'alpha': 0.02395026619987486, 'fit_intercept': False, 'normalize': True}
# -4.418 (+/-0.458) for {'alpha': 0.02395026619987486, 'fit_intercept': False, 'normalize': False}
# -5.779 (+/-0.349) for {'alpha': 0.04175318936560404, 'fit_intercept': True, 'normalize': True}
# -4.361 (+/-0.433) for {'alpha': 0.04175318936560404, 'fit_intercept': True, 'normalize': False}
# -4.427 (+/-0.457) for {'alpha': 0.04175318936560404, 'fit_intercept': False, 'normalize': True}
# -4.427 (+/-0.457) for {'alpha': 0.04175318936560404, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 0.07278953843983153, 'fit_intercept': True, 'normalize': True}
# -4.385 (+/-0.445) for {'alpha': 0.07278953843983153, 'fit_intercept': True, 'normalize': False}
# -4.450 (+/-0.455) for {'alpha': 0.07278953843983153, 'fit_intercept': False, 'normalize': True}
# -4.450 (+/-0.455) for {'alpha': 0.07278953843983153, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 0.12689610031679235, 'fit_intercept': True, 'normalize': True}
# -4.435 (+/-0.457) for {'alpha': 0.12689610031679235, 'fit_intercept': True, 'normalize': False}
# -4.488 (+/-0.440) for {'alpha': 0.12689610031679235, 'fit_intercept': False, 'normalize': True}
# -4.488 (+/-0.440) for {'alpha': 0.12689610031679235, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 0.22122162910704501, 'fit_intercept': True, 'normalize': True}
# -4.483 (+/-0.438) for {'alpha': 0.22122162910704501, 'fit_intercept': True, 'normalize': False}
# -4.499 (+/-0.443) for {'alpha': 0.22122162910704501, 'fit_intercept': False, 'normalize': True}
# -4.499 (+/-0.443) for {'alpha': 0.22122162910704501, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 0.38566204211634725, 'fit_intercept': True, 'normalize': True}
# -4.589 (+/-0.399) for {'alpha': 0.38566204211634725, 'fit_intercept': True, 'normalize': False}
# -4.511 (+/-0.436) for {'alpha': 0.38566204211634725, 'fit_intercept': False, 'normalize': True}
# -4.511 (+/-0.436) for {'alpha': 0.38566204211634725, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 0.6723357536499335, 'fit_intercept': True, 'normalize': True}
# -4.757 (+/-0.342) for {'alpha': 0.6723357536499335, 'fit_intercept': True, 'normalize': False}
# -4.553 (+/-0.414) for {'alpha': 0.6723357536499335, 'fit_intercept': False, 'normalize': True}
# -4.553 (+/-0.414) for {'alpha': 0.6723357536499335, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 1.1721022975334818, 'fit_intercept': True, 'normalize': True}
# -4.810 (+/-0.256) for {'alpha': 1.1721022975334818, 'fit_intercept': True, 'normalize': False}
# -4.657 (+/-0.383) for {'alpha': 1.1721022975334818, 'fit_intercept': False, 'normalize': True}
# -4.657 (+/-0.383) for {'alpha': 1.1721022975334818, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 2.043359717856944, 'fit_intercept': True, 'normalize': True}
# -4.957 (+/-0.177) for {'alpha': 2.043359717856944, 'fit_intercept': True, 'normalize': False}
# -4.881 (+/-0.361) for {'alpha': 2.043359717856944, 'fit_intercept': False, 'normalize': True}
# -4.881 (+/-0.361) for {'alpha': 2.043359717856944, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 3.562247890262444, 'fit_intercept': True, 'normalize': True}
# -5.343 (+/-0.315) for {'alpha': 3.562247890262444, 'fit_intercept': True, 'normalize': False}
# -5.243 (+/-0.347) for {'alpha': 3.562247890262444, 'fit_intercept': False, 'normalize': True}
# -5.243 (+/-0.347) for {'alpha': 3.562247890262444, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 6.2101694189156165, 'fit_intercept': True, 'normalize': True}
# -5.625 (+/-0.329) for {'alpha': 6.2101694189156165, 'fit_intercept': True, 'normalize': False}
# -6.148 (+/-0.502) for {'alpha': 6.2101694189156165, 'fit_intercept': False, 'normalize': True}
# -6.148 (+/-0.502) for {'alpha': 6.2101694189156165, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 10.82636733874054, 'fit_intercept': True, 'normalize': True}
# -5.625 (+/-0.329) for {'alpha': 10.82636733874054, 'fit_intercept': True, 'normalize': False}
# -8.279 (+/-1.098) for {'alpha': 10.82636733874054, 'fit_intercept': False, 'normalize': True}
# -8.279 (+/-1.098) for {'alpha': 10.82636733874054, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 18.873918221350994, 'fit_intercept': True, 'normalize': True}
# -5.627 (+/-0.329) for {'alpha': 18.873918221350994, 'fit_intercept': True, 'normalize': False}
# -8.714 (+/-0.920) for {'alpha': 18.873918221350994, 'fit_intercept': False, 'normalize': True}
# -8.714 (+/-0.920) for {'alpha': 18.873918221350994, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 32.90344562312671, 'fit_intercept': True, 'normalize': True}
# -5.630 (+/-0.330) for {'alpha': 32.90344562312671, 'fit_intercept': True, 'normalize': False}
# -8.715 (+/-0.927) for {'alpha': 32.90344562312671, 'fit_intercept': False, 'normalize': True}
# -8.715 (+/-0.927) for {'alpha': 32.90344562312671, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 57.361525104486816, 'fit_intercept': True, 'normalize': True}
# -5.642 (+/-0.332) for {'alpha': 57.361525104486816, 'fit_intercept': True, 'normalize': False}
# -8.717 (+/-0.939) for {'alpha': 57.361525104486816, 'fit_intercept': False, 'normalize': True}
# -8.717 (+/-0.939) for {'alpha': 57.361525104486816, 'fit_intercept': False, 'normalize': False}
# -5.786 (+/-0.344) for {'alpha': 100.0, 'fit_intercept': True, 'normalize': True}
# -5.679 (+/-0.337) for {'alpha': 100.0, 'fit_intercept': True, 'normalize': False}
# -8.725 (+/-0.959) for {'alpha': 100.0, 'fit_intercept': False, 'normalize': True}
# -8.725 (+/-0.959) for {'alpha': 100.0, 'fit_intercept': False, 'normalize': False}
#
# Mean squared error: 4.31
# Variance score: 0.22

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

trace = go.Table(
    header=dict(values=[""]+[name for name in names], 
                fill = dict(color='#a1c3d1')),
    cells=dict(values=results, 
              fill = dict(color='#EDFAFF')))

layout = go.Layout(
    title=go.layout.Title(
        text='Comparison of linear models',
        xref='paper',
        x=0
    )
)
fig = go.Figure(data=[trace], layout=layout)
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="86958447-3ff3-4027-81e5-513e3ec8fb2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("86958447-3ff3-4027-81e5-513e3ec8fb2d")) {
#                     Plotly.newPlot(
#                         '86958447-3ff3-4027-81e5-513e3ec8fb2d',
#                         [{"cells": {"fill": {"color": "#EDFAFF"}, "values": [["mean squared error", "variance score"], [4.316601318495479, 0.21465902141604676], [4.311849001002545, 0.21552363442870814], [4.311727340483382, 0.21554576873857945]]}, "header": {"fill": {"color": "#a1c3d1"}, "values": ["", "linear regression", "lasso", "elastic net"]}, "type": "table", "uid": "5db2f940-b17e-45fa-94d7-b1b12f6205dc"}],
#                         {"title": {"text": "Comparison of linear models", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('86958447-3ff3-4027-81e5-513e3ec8fb2d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
